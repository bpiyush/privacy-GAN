# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/mnt/experiments/privacy-GAN/')

# %%
from data import *
from utils.generic import *
from utils.data import *
from data.clean_dataset import clean_dataset

# %% [markdown]
# ## LA-City Dataset

# %%
clean_dataset('lacity')
# Out:
# <---------- Cleaning lacity dataset ---------->
# => Seperating numeric and non_numeric columns ...
# => Dropping direct identifiers ...
# => Replacing NaN values by column mean ...
# => Shifting the target column to the last index ...
# /home/ec2-user/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# => Saving cleaned dataset ...

# %%
raw_lacity = load_dataset('lacity', 'raw')
clean_lacity = load_dataset('lacity', 'clean')

# %%
raw_lacity.columns
# Out:
# Index(['Row ID', 'Year', 'Department Title', 'Payroll Department',
#        'Record Number', 'Job Class Title', 'Employment Type',
#        'Hourly or Event Rate', 'Projected Annual Salary', 'Q1 Payments',
#        'Q2 Payments', 'Q3 Payments', 'Q4 Payments', 'Payments Over Base Pay',
#        '% Over Base Pay', 'Total Payments', 'Base Pay', 'Permanent Bonus Pay',
#        'Longevity Bonus Pay', 'Temporary Bonus Pay', 'Lump Sum Pay',
#        'Overtime Pay', 'Other Pay & Adjustments',
#        'Other Pay (Payroll Explorer)', 'MOU', 'MOU Title', 'FMS Department',
#        'Job Class', 'Pay Grade', 'Average Health Cost', 'Average Dental Cost',
#        'Average Basic Life', 'Average Benefit Cost', 'Benefits Plan',
#        'Job Class Link'],
#       dtype='object')

# %%
clean_lacity.columns
# Out:
# Index(['Year', 'Payroll Department', 'Hourly or Event Rate', 'Q1 Payments',
#        'Q2 Payments', 'Q3 Payments', 'Q4 Payments', 'Payments Over Base Pay',
#        'Total Payments', 'Base Pay', 'Permanent Bonus Pay',
#        'Longevity Bonus Pay', 'Temporary Bonus Pay', 'Lump Sum Pay',
#        'Overtime Pay', 'Other Pay & Adjustments',
#        'Other Pay (Payroll Explorer)', 'FMS Department', 'Job Class',
#        'Average Health Cost', 'Average Dental Cost', 'Average Basic Life',
#        'Average Benefit Cost', 'Pay Grade', 'Job Class Title',
#        'Department Title', 'MOU Title', 'Employment Type', 'MOU',
#        'Benefits Plan', '% Over Base Pay', 'Projected Annual Salary'],
#       dtype='object')

# %%
raw_lacity.head(3)
# Out:
#              Row ID  Year Department Title  Payroll Department Record Number  \
# 0  3-1000027830ctFu  2013    Police (LAPD)              4301.0    1000027830
# 1  3-1000155488ctFu  2013    Police (LAPD)              4302.0    1000155488
# 2  3-1000194958ctFu  2013    Police (LAPD)              4301.0    1000194958
#
#        Job Class Title Employment Type  Hourly or Event Rate  \
# 0  Police Detective II       Full Time                 53.16
# 1         Clerk Typist       Full Time                 23.77
# 2    Police Sergeant I       Full Time                 60.80
#
#    Projected Annual Salary  Q1 Payments  \
# 0                110998.08     24931.20
# 1                 49623.67     11343.96
# 2                126950.40     24184.00
#
#                     ...                                MOU Title  \
# 0                   ...                     POLICE OFFICERS UNIT
# 1                   ...                            CLERICAL UNIT
# ...

# %%
clean_lacity.head(3)
# Out:
#    Year  Payroll Department  Hourly or Event Rate  Q1 Payments  Q2 Payments  \
# 0  2013              4301.0                 53.16     24931.20     29181.61
# 1  2013              4302.0                 23.77     11343.96     13212.37
# 2  2013              4301.0                 60.80     24184.00     28327.20
#
#    Q3 Payments  Q4 Payments  Payments Over Base Pay  Total Payments  \
# 0     26545.80     29605.30                 4499.12       110263.91
# 1     11508.36     13442.53                 1844.82        49507.22
# 2     28744.20     33224.88                13192.43       114480.28
#
#     Base Pay           ...             Average Benefit Cost  Pay Grade  \
# 0  105764.79           ...                         12740.52          2
# 1   47662.40           ...                         11126.88          0
# 2  101287.85           ...                         12740.52          1
#
#        Job Class Title  Department Title             MOU Title  \
# ...

# %%
save_subset_of_dataset('lacity', num_examples_reqd=18000)
# Out:
# => Sampling a subset of 18000 examples from dataset ...
# => Saving the new subset dataset ...

# %%
clean_subset_lacity = load_dataset('lacity', 'clean_subset')

# %%
clean_subset_lacity.head()
# Out:
#    Year  Payroll Department  Hourly or Event Rate  Q1 Payments  Q2 Payments  \
# 0  2013              4301.0                 53.16     24931.20     29181.61
# 1  2013              4302.0                 23.77     11343.96     13212.37
# 2  2013              4301.0                 60.80     24184.00     28327.20
# 3  2013              8701.0                 30.23     15319.59     17762.14
# 4  2013              4301.0                 60.98     29391.20     36591.20
#
#    Q3 Payments  Q4 Payments  Payments Over Base Pay  Total Payments  \
# 0     26545.80     29605.30                 4499.12       110263.91
# 1     11508.36     13442.53                 1844.82        49507.22
# 2     28744.20     33224.88                13192.43       114480.28
# 3     15601.85     18233.32                 5924.08        66916.90
# 4     32904.81     37234.03                18034.53       136121.24
#
#     Base Pay           ...             Average Benefit Cost  Pay Grade  \
# ...

# %% [markdown]
# ## Adult dataset

# %%
clean_dataset('adult')
# Out:
# <---------- Cleaning adult dataset ---------->
# => Seperating numeric and non_numeric columns ...
# => Dropping direct identifiers ...
# => Replacing NaN values by column mean ...
# => Shifting the target column to the last index ...
# => Saving cleaned dataset ...

# %%
raw_adult = load_dataset('adult', 'raw')
clean_adult = load_dataset('adult', 'clean')

# %%
raw_adult.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
clean_adult.columns
# Out:
# Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'sex', 'workclass', 'relationship', 'education',
#        'occupation', 'native-country', 'marital-status', 'race', 'income'],
#       dtype='object')

# %%
raw_adult.head(3)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country income
# 0          2174             0              40   United-States  <=50K
# 1             0             0              13   United-States  <=50K
# 2             0             0              40   United-States  <=50K

# %%
clean_adult.head(3)
# Out:
#    age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
#
#      sex          workclass    relationship   education          occupation  \
# 0   Male          State-gov   Not-in-family   Bachelors        Adm-clerical
# 1   Male   Self-emp-not-inc         Husband   Bachelors     Exec-managerial
# 2   Male            Private   Not-in-family     HS-grad   Handlers-cleaners
#
#    native-country       marital-status    race income
# 0   United-States        Never-married   White  <=50K
# 1   United-States   Married-civ-spouse   White  <=50K
# 2   United-States             Divorced   White  <=50K
